# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy   as np
import sklearn as skl

import matplotlib.pyplot as plt
import seaborn           as srn

from sklearn.model_selection       import train_test_split
from sklearn.svm                   import OneClassSVM
from sklearn.kernel_approximation  import Nystroem
from sklearn.neighbors             import KernelDensity
from sklearn.model_selection       import GridSearchCV
from sklearn.metrics               import pairwise_distances
from scipy.stats                   import beta
import random
import numpy as np
import random
import numpy as np
import seaborn as sns, numpy as np
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import sys
from sklearn import svm
import time
import tensorflow as tf
from sklearn.metrics import precision_score,accuracy_score
import csv
from itertools import izip_longest

# %% [markdown]
# Generate samples from a Beta(2, 2) distribution.

# %%
np.random.seed(42)
N = 10**4

X     = beta.rvs(a = 2, b = 2, size = N)[:,np.newaxis]
pStar = lambda x: beta.pdf(x, a = 2, b = 2)

XTr, XTe = train_test_split(X, train_size = 0.80, test_size = 0.20, random_state = 42)
XTe      = XTe[np.argsort(XTe.flatten()),:]

# %%
# results = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/sanity_results/"
# decision_scorePath = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/scores/"
# df_usps_scores  = {}
# activations = ["Linear","Sigmoid"]
# methods = ["Linear","RBF"]
# path = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/scores/"

results = "./sanity_results/"
decision_scorePath = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/scores/"
df_usps_scores  = {}
activations = ["Linear","Sigmoid"]
methods = ["Linear","RBF"]
path = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/scores/"
outfile = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/sanity_beta_distribution/weights/"
nu = 0.1

def write_Scores2Csv(train, trainscore, test, testscore,filename):

    data = np.concatenate((train, test))
    score= np.concatenate((trainscore,testscore))
    data = data.tolist()
    score = score.tolist()
    with open(filename, 'a') as myfile:
        wr = csv.writer(myfile)
        wr.writerow(("x", "score"))
    for row in range(0,len(data)):
        with open(filename,
                  'a') as myfile:
            wr = csv.writer(myfile)

            wr.writerow((" ".join(str(x) for x in data[row]), " ".join(str(x) for x in score[row])))


def write_decisionScores2Csv(path, filename, positiveScores, negativeScores):

    newfilePath = path+filename
    print "Writing file to ", path+filename
    poslist = positiveScores.tolist()
    neglist = negativeScores.tolist()

    # rows = zip(poslist, neglist)
    d = [poslist, neglist]
    export_data = izip_longest(*d, fillvalue='')
    with open(newfilePath, 'w') as myfile:
        wr = csv.writer(myfile)
        wr.writerow(("Normal", "Anomaly"))
        wr.writerows(export_data)
    myfile.close()

    return


def tf_OneClass_NN_sigmoid(data_train,data_test):

    tf.reset_default_graph()

    train_X = data_train

    RANDOM_SEED = 42
    tf.set_random_seed(RANDOM_SEED)

     # Layer's sizes
    x_size = train_X.shape[1]   # Number of input nodes: 4 features and 1 bias
    h_size = 200                # Number of hidden nodes
    y_size = 1   # Number of outcomes (3 iris flowers)
    D = x_size
    K = h_size

    theta = np.random.normal(0, 1, K + K*D + 1)
    rvalue = np.random.normal(0,1,(len(train_X),y_size))
  

    def init_weights(shape):
        """ Weight initialization """
        weights = tf.random_normal(shape,mean=0, stddev=0.5)
        return tf.Variable(weights,trainable=False)

    def forwardprop(X, w_1, w_2):
        """
        Forward-propagation.
        IMPORTANT: yhat is not softmax since TensorFlow's softmax_cross_entropy_with_logits() does that internally.
        """
        X = tf.cast(X, tf.float32)
        w_1 = tf.cast(w_1, tf.float32)
        w_2 = tf.cast(w_2, tf.float32)
        h    = tf.nn.sigmoid(tf.matmul(X, w_1))  # The \sigma function
        yhat = tf.matmul(h, w_2)  # The \varphi function
        return yhat

#     g   = lambda x : 1/(1 + tf.exp(-x))
#     g   = lambda x : tf.nn.sigmoid(x)
    g   = lambda x : (1/np.sqrt(h_size) )*tf.cos(x/0.02)

    def nnScore(X, w, V, g,bias1,bias2):
        X = tf.cast(X, tf.float32)
        w = tf.cast(w, tf.float32)
        V = tf.cast(V, tf.float32)
        y_hat =tf.matmul(g((tf.matmul(X, w)+bias1)), V) +bias2
#         return tf.matmul(g((tf.matmul(X, w))), V)
        return y_hat

    def relu(x):
        y = x
        y[y < 0] = 0
        return y
    
    
       # For testing the algorithm
    def compute_LossValue(X, nu, w1, w2, g, r,bias1,bias2):
        w = w1
        V = w2

        X = tf.cast(X, tf.float32)
        w = tf.cast(w1, tf.float32)
        V = tf.cast(w2, tf.float32)
        term1 = 0.5 * tf.reduce_sum(tf.square(w))
        term2 = 0.5 * tf.reduce_sum(tf.square(V))


#         term3 = 1 / nu * tf.reduce_mean(tf.maximum(0.0, r - nnScore(X, w, V, g,bias1,bias2)))
       
        term3 = 1 / nu * tf.reduce_mean(tf.nn.relu(r - nnScore(X, w, V, g,bias1,bias2)))
        term4 = -r
     
        y_hat = nnScore(X, w, V, g,bias1,bias2)
    
        totalCost = term1 + term2 + term3 + term4
        
        loss=   [term1,term2,term3,term4,totalCost,y_hat]
        return loss
    
    
    def ocnn_obj(theta, X, nu, w1, w2, g,r,bias1,bias2):

        w = w1
        V = w2


        X = tf.cast(X, tf.float32)
        w = tf.cast(w1, tf.float32)
        V = tf.cast(w2, tf.float32)


        term1 = 0.5  * tf.reduce_sum(w**2)
        term2 = 0.5  * tf.reduce_sum(V**2)
        term3 = 1/nu * tf.reduce_mean(tf.nn.relu(r - nnScore(X, w, V, g,bias1,bias2)))
        term4 = -r

        return term1 + term2 + term3 + term4


    # For testing the algorithm
    test_X = data_test


    # Symbols
    X = tf.placeholder("float32", shape=[None, x_size])

    r = tf.get_variable("r", dtype=tf.float32,shape=())

    # Weight initializations
    w_1 = init_weights((x_size, h_size))
    #     w_2 = init_weights((h_size, y_size))
    weights = tf.random_normal((h_size, y_size),mean=0, stddev=0.1)
#     w_2 =  tf.Variable(weights)
    ocsvm_wt = np.load(outfile+"ocsvm_wt.npy")
    w_2 =tf.get_variable("tf_var_initialized_ocsvm",
                                 initializer=ocsvm_wt)
    
    bias1 = tf.Variable(initial_value=[[1.0]], dtype=tf.float32,trainable=False)
    bias2 = tf.Variable(initial_value=[[0.0]], dtype=tf.float32,trainable=False)

    # Forward propagation
    yhat    = forwardprop(X, w_1, w_2)
    predict = tf.argmax(yhat, axis=1)


    # Backward propagation
    # cost    = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=yhat))
    cost    = ocnn_obj(theta, X, nu, w_1, w_2, g,r,bias1,bias2)
#     updates = tf.train.GradientDescentOptimizer(0.0001).minimize(cost)
    updates = tf.train.AdamOptimizer(4.7 * 1e-1).minimize(cost)

    # Run SGD
    sess = tf.Session()
    init = tf.global_variables_initializer()
    sess.run(init)
    rvalue = 0.1
    start_time = time.time()
    for epoch in range(100):
            # Train with each example
                sess.run(updates, feed_dict={X: train_X})
                
               
                with sess.as_default():
                    svalue = nnScore(train_X, w_1, w_2, g,bias1,bias2)  
                    print "Checking svalue <rvalue: ",np.mean(svalue.eval() < rvalue)
#                     rval = svalue.eval()
#                     rvalue = np.percentile(rval,q=100*nu)
                    
                    print "Checking svalue <rvalue: ",np.mean(svalue.eval() < rvalue)
                    costvalue = compute_LossValue(train_X, nu, w_1, w_2, g, rvalue,bias1,bias2)
                    term1 = costvalue[0].eval()
                    term2 = costvalue[1].eval()
                    term3 = costvalue[2].eval()
                    term4 = costvalue[3]
                    term5 = costvalue[4].eval()
                    yval = costvalue[5].eval()
  
                print("Epoch = %d, r = %f"
                  % (epoch + 1,rvalue))
                print ("Cost:(term1,term2,term3,term4,term5,yhat) ", np.mean(term1),np.mean(term2),(term3),np.mean(term4),np.mean(term5),np.mean(yval))
                print ("Total Cost: ",np.mean(term5))
                
                with sess.as_default():
                    print "Checking svalue <rvalue: ",np.mean(svalue.eval() < rvalue)
                print "================================"
                print "================================"

    trainTime = time.time() - start_time

    start_time = time.time()
    train = nnScore(train_X, w_1, w_2, g,bias1,bias2)
    test = nnScore(test_X, w_1, w_2, g,bias1,bias2)
    testTime = time.time() - start_time
    with sess.as_default():
        np_w_1= w_1.eval()
        np_w_2= w_2.eval()
        np_bias1= bias1.eval()
        arrayTrain = train.eval()
        arrayTest = test.eval()
    #     rstar = r.eval()

    rstar =rvalue
    sess.close()
    print "Session Closed!!!"


#     pos_decisionScore = arrayTrain-rstar
#     neg_decisionScore = arrayTest-rstar
    pos_decisionScore = arrayTrain
    neg_decisionScore = arrayTest
    # save the w_1 and bias1 to numpy array
    np.save(outfile+"w_1", np_w_1)
    np.save(outfile+"w_2", np_w_2)
    np.save(outfile+"bias1",np_bias1)

    write_Scores2Csv(train_X,pos_decisionScore,test_X,neg_decisionScore,path+"OC_NN.csv")

    write_decisionScores2Csv(decision_scorePath,"Synthetic_OC-NN_Sigmoid.csv",pos_decisionScore,neg_decisionScore)


    return [pos_decisionScore, neg_decisionScore,trainTime,testTime,rstar]

# %% [markdown]
# ### Call OC-NN Sigmoid

# %%
[train_decisionScore, test_decisionScore,trainTime,testTime,rstar_OCNN] = tf_OneClass_NN_sigmoid(XTr,XTe)
# Out:
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 1, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18802720.0, 723.3776, -0.1, 18803470.0, 120.02014)
# ('Total Cost: ', 18803470.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 2, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18762540.0, 722.6699, -0.1, 18763288.0, 119.88606)
# ('Total Cost: ', 18763288.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 3, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18722406.0, 721.9622, -0.1, 18723154.0, 119.751976)
# ('Total Cost: ', 18723154.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 4, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18682320.0, 721.25464, -0.1, 18683068.0, 119.6179)
# ('Total Cost: ', 18683068.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 5, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18642280.0, 720.5469, -0.1, 18643026.0, 119.48382)
# ('Total Cost: ', 18643026.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 6, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18602288.0, 719.8395, -0.1, 18603034.0, 119.34978)
# ('Total Cost: ', 18603034.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 7, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18562348.0, 719.1321, -0.1, 18563094.0, 119.215744)
# ('Total Cost: ', 18563094.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 8, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18522456.0, 718.4247, -0.1, 18523200.0, 119.081726)
# ('Total Cost: ', 18523200.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 9, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18482612.0, 717.7175, -0.1, 18483356.0, 118.94773)
# ('Total Cost: ', 18483356.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 10, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18442822.0, 717.0102, -0.1, 18443566.0, 118.81377)
# ('Total Cost: ', 18443566.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 11, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18403084.0, 716.3032, -0.1, 18403826.0, 118.679825)
# ('Total Cost: ', 18403826.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 12, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18363400.0, 715.5964, -0.1, 18364142.0, 118.545906)
# ('Total Cost: ', 18364142.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 13, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18323764.0, 714.88965, -0.1, 18324504.0, 118.412025)
# ('Total Cost: ', 18324504.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 14, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18284184.0, 714.18304, -0.1, 18284924.0, 118.278175)
# ('Total Cost: ', 18284924.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 15, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18244660.0, 713.47656, -0.1, 18245400.0, 118.14435)
# ('Total Cost: ', 18245400.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 16, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18205190.0, 712.77026, -0.1, 18205928.0, 118.01057)
# ('Total Cost: ', 18205928.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.3445
# Checking svalue <rvalue:  0.3445
# Epoch = 17, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18165776.0, 712.06433, -0.1, 18166514.0, 117.87683)
# ('Total Cost: ', 18166514.0)
# Checking svalue <rvalue:  0.3445
# ================================
# ================================
# Checking svalue <rvalue:  0.3445
# Checking svalue <rvalue:  0.3445
# Epoch = 18, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18126418.0, 711.3584, -0.1, 18127156.0, 117.743126)
# ('Total Cost: ', 18127156.0)
# Checking svalue <rvalue:  0.3445
# ================================
# ================================
# Checking svalue <rvalue:  0.3445
# Checking svalue <rvalue:  0.3445
# Epoch = 19, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18087116.0, 710.65283, -0.1, 18087852.0, 117.609474)
# ('Total Cost: ', 18087852.0)
# Checking svalue <rvalue:  0.3445
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 20, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18047870.0, 709.9479, -0.1, 18048606.0, 117.47586)
# ('Total Cost: ', 18048606.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 21, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 18008680.0, 709.2425, -0.1, 18009416.0, 117.3423)
# ('Total Cost: ', 18009416.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 22, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17969554.0, 708.53784, -0.1, 17970288.0, 117.20878)
# ('Total Cost: ', 17970288.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344375
# Checking svalue <rvalue:  0.344375
# Epoch = 23, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17930480.0, 707.8335, -0.1, 17931214.0, 117.07531)
# ('Total Cost: ', 17931214.0)
# Checking svalue <rvalue:  0.344375
# ================================
# ================================
# Checking svalue <rvalue:  0.344625
# Checking svalue <rvalue:  0.344625
# Epoch = 24, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17891470.0, 707.129, -0.1, 17892204.0, 116.94189)
# ('Total Cost: ', 17892204.0)
# Checking svalue <rvalue:  0.344625
# ================================
# ================================
# Checking svalue <rvalue:  0.344625
# Checking svalue <rvalue:  0.344625
# Epoch = 25, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17852514.0, 706.42505, -0.1, 17853246.0, 116.80853)
# ('Total Cost: ', 17853246.0)
# Checking svalue <rvalue:  0.344625
# ================================
# ================================
# Checking svalue <rvalue:  0.344625
# Checking svalue <rvalue:  0.344625
# Epoch = 26, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17813622.0, 705.7217, -0.1, 17814354.0, 116.67522)
# ('Total Cost: ', 17814354.0)
# Checking svalue <rvalue:  0.344625
# ================================
# ================================
# Checking svalue <rvalue:  0.344625
# Checking svalue <rvalue:  0.344625
# Epoch = 27, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17774786.0, 705.0183, -0.1, 17775518.0, 116.54197)
# ('Total Cost: ', 17775518.0)
# Checking svalue <rvalue:  0.344625
# ================================
# ================================
# Checking svalue <rvalue:  0.344625
# Checking svalue <rvalue:  0.344625
# Epoch = 28, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17736012.0, 704.3152, -0.1, 17736742.0, 116.40877)
# ('Total Cost: ', 17736742.0)
# Checking svalue <rvalue:  0.344625
# ================================
# ================================
# Checking svalue <rvalue:  0.344625
# Checking svalue <rvalue:  0.344625
# Epoch = 29, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17697298.0, 703.6122, -0.1, 17698028.0, 116.275635)
# ('Total Cost: ', 17698028.0)
# Checking svalue <rvalue:  0.344625
# ================================
# ================================
# Checking svalue <rvalue:  0.344625
# Checking svalue <rvalue:  0.344625
# Epoch = 30, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17658644.0, 702.90985, -0.1, 17659372.0, 116.14255)
# ('Total Cost: ', 17659372.0)
# Checking svalue <rvalue:  0.344625
# ================================
# ================================
# Checking svalue <rvalue:  0.344625
# Checking svalue <rvalue:  0.344625
# Epoch = 31, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17620052.0, 702.20734, -0.1, 17620780.0, 116.00953)
# ('Total Cost: ', 17620780.0)
# Checking svalue <rvalue:  0.344625
# ================================
# ================================
# Checking svalue <rvalue:  0.34475
# Checking svalue <rvalue:  0.34475
# Epoch = 32, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17581520.0, 701.5056, -0.1, 17582248.0, 115.87657)
# ('Total Cost: ', 17582248.0)
# Checking svalue <rvalue:  0.34475
# ================================
# ================================
# Checking svalue <rvalue:  0.34475
# Checking svalue <rvalue:  0.34475
# Epoch = 33, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17543048.0, 700.8038, -0.1, 17543774.0, 115.743675)
# ('Total Cost: ', 17543774.0)
# Checking svalue <rvalue:  0.34475
# ================================
# ================================
# Checking svalue <rvalue:  0.34475
# Checking svalue <rvalue:  0.34475
# Epoch = 34, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17504640.0, 700.10266, -0.1, 17505366.0, 115.61083)
# ('Total Cost: ', 17505366.0)
# Checking svalue <rvalue:  0.34475
# ================================
# ================================
# Checking svalue <rvalue:  0.344875
# Checking svalue <rvalue:  0.344875
# Epoch = 35, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17466294.0, 699.40173, -0.1, 17467020.0, 115.478065)
# ('Total Cost: ', 17467020.0)
# Checking svalue <rvalue:  0.344875
# ================================
# ================================
# Checking svalue <rvalue:  0.344875
# Checking svalue <rvalue:  0.344875
# Epoch = 36, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17428008.0, 698.70123, -0.1, 17428732.0, 115.345375)
# ('Total Cost: ', 17428732.0)
# Checking svalue <rvalue:  0.344875
# ================================
# ================================
# Checking svalue <rvalue:  0.345
# Checking svalue <rvalue:  0.345
# Epoch = 37, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17389784.0, 698.001, -0.1, 17390508.0, 115.212715)
# ('Total Cost: ', 17390508.0)
# Checking svalue <rvalue:  0.345
# ================================
# ================================
# Checking svalue <rvalue:  0.345
# Checking svalue <rvalue:  0.345
# Epoch = 38, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17351624.0, 697.3011, -0.1, 17352348.0, 115.08015)
# ('Total Cost: ', 17352348.0)
# Checking svalue <rvalue:  0.345
# ================================
# ================================
# Checking svalue <rvalue:  0.345
# Checking svalue <rvalue:  0.345
# Epoch = 39, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17313526.0, 696.60144, -0.1, 17314248.0, 114.94764)
# ('Total Cost: ', 17314248.0)
# Checking svalue <rvalue:  0.345
# ================================
# ================================
# Checking svalue <rvalue:  0.345
# Checking svalue <rvalue:  0.345
# Epoch = 40, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17275488.0, 695.9022, -0.1, 17276210.0, 114.8152)
# ('Total Cost: ', 17276210.0)
# Checking svalue <rvalue:  0.345
# ================================
# ================================
# Checking svalue <rvalue:  0.345
# Checking svalue <rvalue:  0.345
# Epoch = 41, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17237516.0, 695.2031, -0.1, 17238238.0, 114.68283)
# ('Total Cost: ', 17238238.0)
# Checking svalue <rvalue:  0.345
# ================================
# ================================
# Checking svalue <rvalue:  0.345
# Checking svalue <rvalue:  0.345
# Epoch = 42, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17199604.0, 694.5049, -0.1, 17200324.0, 114.55053)
# ('Total Cost: ', 17200324.0)
# Checking svalue <rvalue:  0.345
# ================================
# ================================
# Checking svalue <rvalue:  0.345
# Checking svalue <rvalue:  0.345
# Epoch = 43, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17161756.0, 693.8063, -0.1, 17162476.0, 114.41829)
# ('Total Cost: ', 17162476.0)
# Checking svalue <rvalue:  0.345
# ================================
# ================================
# Checking svalue <rvalue:  0.344875
# Checking svalue <rvalue:  0.344875
# Epoch = 44, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17123968.0, 693.10864, -0.1, 17124688.0, 114.286125)
# ('Total Cost: ', 17124688.0)
# Checking svalue <rvalue:  0.344875
# ================================
# ================================
# Checking svalue <rvalue:  0.344875
# Checking svalue <rvalue:  0.344875
# Epoch = 45, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17086248.0, 692.411, -0.1, 17086966.0, 114.15403)
# ('Total Cost: ', 17086966.0)
# Checking svalue <rvalue:  0.344875
# ================================
# ================================
# Checking svalue <rvalue:  0.345
# Checking svalue <rvalue:  0.345
# Epoch = 46, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17048586.0, 691.7142, -0.1, 17049304.0, 114.02202)
# ('Total Cost: ', 17049304.0)
# Checking svalue <rvalue:  0.345
# ================================
# ================================
# Checking svalue <rvalue:  0.345
# Checking svalue <rvalue:  0.345
# Epoch = 47, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 17010992.0, 691.01733, -0.1, 17011710.0, 113.89006)
# ('Total Cost: ', 17011710.0)
# Checking svalue <rvalue:  0.345
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 48, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16973456.0, 690.3208, -0.1, 16974172.0, 113.75817)
# ('Total Cost: ', 16974172.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 49, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16935986.0, 689.62476, -0.1, 16936702.0, 113.626366)
# ('Total Cost: ', 16936702.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 50, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16898576.0, 688.92896, -0.1, 16899290.0, 113.49462)
# ('Total Cost: ', 16899290.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 51, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16861228.0, 688.2337, -0.1, 16861942.0, 113.36295)
# ('Total Cost: ', 16861942.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 52, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16823950.0, 687.53894, -0.1, 16824664.0, 113.23136)
# ('Total Cost: ', 16824664.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.34525
# Checking svalue <rvalue:  0.34525
# Epoch = 53, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16786730.0, 686.8442, -0.1, 16787442.0, 113.099846)
# ('Total Cost: ', 16787442.0)
# Checking svalue <rvalue:  0.34525
# ================================
# ================================
# Checking svalue <rvalue:  0.34525
# Checking svalue <rvalue:  0.34525
# Epoch = 54, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16749573.0, 686.15027, -0.1, 16750285.0, 112.9684)
# ('Total Cost: ', 16750285.0)
# Checking svalue <rvalue:  0.34525
# ================================
# ================================
# Checking svalue <rvalue:  0.34525
# Checking svalue <rvalue:  0.34525
# Epoch = 55, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16712480.0, 685.4562, -0.1, 16713191.0, 112.83702)
# ('Total Cost: ', 16713191.0)
# Checking svalue <rvalue:  0.34525
# ================================
# ================================
# Checking svalue <rvalue:  0.34525
# Checking svalue <rvalue:  0.34525
# Epoch = 56, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16675449.0, 684.7628, -0.1, 16676160.0, 112.70572)
# ('Total Cost: ', 16676160.0)
# Checking svalue <rvalue:  0.34525
# ================================
# ================================
# Checking svalue <rvalue:  0.34525
# Checking svalue <rvalue:  0.34525
# Epoch = 57, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16638482.0, 684.06976, -0.1, 16639192.0, 112.574486)
# ('Total Cost: ', 16639192.0)
# Checking svalue <rvalue:  0.34525
# ================================
# ================================
# Checking svalue <rvalue:  0.34525
# Checking svalue <rvalue:  0.34525
# Epoch = 58, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16601577.0, 683.3767, -0.1, 16602286.0, 112.44334)
# ('Total Cost: ', 16602286.0)
# Checking svalue <rvalue:  0.34525
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 59, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16564737.0, 682.6844, -0.1, 16565446.0, 112.31226)
# ('Total Cost: ', 16565446.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 60, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16527957.0, 681.9922, -0.1, 16528665.0, 112.181244)
# ('Total Cost: ', 16528665.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 61, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16491242.0, 681.3008, -0.1, 16491949.0, 112.050316)
# ('Total Cost: ', 16491949.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 62, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16454588.0, 680.6094, -0.1, 16455295.0, 111.91946)
# ('Total Cost: ', 16455295.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 63, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16417997.0, 679.9183, -0.1, 16418703.0, 111.78867)
# ('Total Cost: ', 16418703.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 64, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16381471.0, 679.22766, -0.1, 16382176.0, 111.65797)
# ('Total Cost: ', 16382176.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 65, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16345004.0, 678.5375, -0.1, 16345709.0, 111.52733)
# ('Total Cost: ', 16345709.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 66, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16308602.0, 677.84784, -0.1, 16309306.0, 111.39677)
# ('Total Cost: ', 16309306.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 67, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16272261.0, 677.15826, -0.1, 16272964.0, 111.26629)
# ('Total Cost: ', 16272964.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 68, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16235984.0, 676.4689, -0.1, 16236686.0, 111.13587)
# ('Total Cost: ', 16236686.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 69, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16199769.0, 675.78015, -0.1, 16200471.0, 111.00555)
# ('Total Cost: ', 16200471.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 70, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16163617.0, 675.0916, -0.1, 16164318.0, 110.87528)
# ('Total Cost: ', 16164318.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.345125
# Checking svalue <rvalue:  0.345125
# Epoch = 71, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16127526.0, 674.40344, -0.1, 16128226.0, 110.745094)
# ('Total Cost: ', 16128226.0)
# Checking svalue <rvalue:  0.345125
# ================================
# ================================
# Checking svalue <rvalue:  0.34525
# Checking svalue <rvalue:  0.34525
# Epoch = 72, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16091498.0, 673.71594, -0.1, 16092198.0, 110.614975)
# ('Total Cost: ', 16092198.0)
# Checking svalue <rvalue:  0.34525
# ================================
# ================================
# Checking svalue <rvalue:  0.34525
# Checking svalue <rvalue:  0.34525
# Epoch = 73, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16055534.0, 673.02856, -0.1, 16056233.0, 110.48495)
# ('Total Cost: ', 16056233.0)
# Checking svalue <rvalue:  0.34525
# ================================
# ================================
# Checking svalue <rvalue:  0.34525
# Checking svalue <rvalue:  0.34525
# Epoch = 74, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 16019630.0, 672.3416, -0.1, 16020328.0, 110.354996)
# ('Total Cost: ', 16020328.0)
# Checking svalue <rvalue:  0.34525
# ================================
# ================================
# Checking svalue <rvalue:  0.34525
# Checking svalue <rvalue:  0.34525
# Epoch = 75, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15983790.0, 671.6555, -0.1, 15984488.0, 110.22511)
# ('Total Cost: ', 15984488.0)
# Checking svalue <rvalue:  0.34525
# ================================
# ================================
# Checking svalue <rvalue:  0.345375
# Checking svalue <rvalue:  0.345375
# Epoch = 76, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15948010.0, 670.96893, -0.1, 15948707.0, 110.0953)
# ('Total Cost: ', 15948707.0)
# Checking svalue <rvalue:  0.345375
# ================================
# ================================
# Checking svalue <rvalue:  0.3455
# Checking svalue <rvalue:  0.3455
# Epoch = 77, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15912294.0, 670.28357, -0.1, 15912990.0, 109.96556)
# ('Total Cost: ', 15912990.0)
# Checking svalue <rvalue:  0.3455
# ================================
# ================================
# Checking svalue <rvalue:  0.3455
# Checking svalue <rvalue:  0.3455
# Epoch = 78, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15876638.0, 669.59827, -0.1, 15877334.0, 109.83591)
# ('Total Cost: ', 15877334.0)
# Checking svalue <rvalue:  0.3455
# ================================
# ================================
# Checking svalue <rvalue:  0.3455
# Checking svalue <rvalue:  0.3455
# Epoch = 79, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15841044.0, 668.9131, -0.1, 15841739.0, 109.70633)
# ('Total Cost: ', 15841739.0)
# Checking svalue <rvalue:  0.3455
# ================================
# ================================
# Checking svalue <rvalue:  0.345375
# Checking svalue <rvalue:  0.345375
# Epoch = 80, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15805513.0, 668.2285, -0.1, 15806207.0, 109.57682)
# ('Total Cost: ', 15806207.0)
# Checking svalue <rvalue:  0.345375
# ================================
# ================================
# Checking svalue <rvalue:  0.345375
# Checking svalue <rvalue:  0.345375
# Epoch = 81, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15770043.0, 667.5445, -0.1, 15770737.0, 109.44739)
# ('Total Cost: ', 15770737.0)
# Checking svalue <rvalue:  0.345375
# ================================
# ================================
# Checking svalue <rvalue:  0.345375
# Checking svalue <rvalue:  0.345375
# Epoch = 82, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15734637.0, 666.86066, -0.1, 15735330.0, 109.31804)
# ('Total Cost: ', 15735330.0)
# Checking svalue <rvalue:  0.345375
# ================================
# ================================
# Checking svalue <rvalue:  0.345375
# Checking svalue <rvalue:  0.345375
# Epoch = 83, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15699289.0, 666.1771, -0.1, 15699981.0, 109.18877)
# ('Total Cost: ', 15699981.0)
# Checking svalue <rvalue:  0.345375
# ================================
# ================================
# Checking svalue <rvalue:  0.345375
# Checking svalue <rvalue:  0.345375
# Epoch = 84, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15664006.0, 665.4938, -0.1, 15664697.0, 109.05956)
# ('Total Cost: ', 15664697.0)
# Checking svalue <rvalue:  0.345375
# ================================
# ================================
# Checking svalue <rvalue:  0.345375
# Checking svalue <rvalue:  0.345375
# Epoch = 85, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15628780.0, 664.81085, -0.1, 15629471.0, 108.93043)
# ('Total Cost: ', 15629471.0)
# Checking svalue <rvalue:  0.345375
# ================================
# ================================
# Checking svalue <rvalue:  0.345375
# Checking svalue <rvalue:  0.345375
# Epoch = 86, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15593620.0, 664.129, -0.1, 15594310.0, 108.80139)
# ('Total Cost: ', 15594310.0)
# Checking svalue <rvalue:  0.345375
# ================================
# ================================
# Checking svalue <rvalue:  0.345375
# Checking svalue <rvalue:  0.345375
# Epoch = 87, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15558520.0, 663.4468, -0.1, 15559209.0, 108.67241)
# ('Total Cost: ', 15559209.0)
# Checking svalue <rvalue:  0.345375
# ================================
# ================================
# Checking svalue <rvalue:  0.3455
# Checking svalue <rvalue:  0.3455
# Epoch = 88, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15523480.0, 662.76514, -0.1, 15524169.0, 108.54351)
# ('Total Cost: ', 15524169.0)
# Checking svalue <rvalue:  0.3455
# ================================
# ================================
# Checking svalue <rvalue:  0.3455
# Checking svalue <rvalue:  0.3455
# Epoch = 89, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15488502.0, 662.08405, -0.1, 15489190.0, 108.41467)
# ('Total Cost: ', 15489190.0)
# Checking svalue <rvalue:  0.3455
# ================================
# ================================
# Checking svalue <rvalue:  0.345625
# Checking svalue <rvalue:  0.345625
# Epoch = 90, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15453586.0, 661.4031, -0.1, 15454273.0, 108.28593)
# ('Total Cost: ', 15454273.0)
# Checking svalue <rvalue:  0.345625
# ================================
# ================================
# Checking svalue <rvalue:  0.345625
# Checking svalue <rvalue:  0.345625
# Epoch = 91, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15418730.0, 660.7227, -0.1, 15419417.0, 108.157265)
# ('Total Cost: ', 15419417.0)
# Checking svalue <rvalue:  0.345625
# ================================
# ================================
# Checking svalue <rvalue:  0.345625
# Checking svalue <rvalue:  0.345625
# Epoch = 92, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15383938.0, 660.0425, -0.1, 15384624.0, 108.02867)
# ('Total Cost: ', 15384624.0)
# Checking svalue <rvalue:  0.345625
# ================================
# ================================
# Checking svalue <rvalue:  0.3455
# Checking svalue <rvalue:  0.3455
# Epoch = 93, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15349202.0, 659.3629, -0.1, 15349887.0, 107.900154)
# ('Total Cost: ', 15349887.0)
# Checking svalue <rvalue:  0.3455
# ================================
# ================================
# Checking svalue <rvalue:  0.3455
# Checking svalue <rvalue:  0.3455
# Epoch = 94, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15314531.0, 658.6838, -0.1, 15315216.0, 107.771706)
# ('Total Cost: ', 15315216.0)
# Checking svalue <rvalue:  0.3455
# ================================
# ================================
# Checking svalue <rvalue:  0.3455
# Checking svalue <rvalue:  0.3455
# Epoch = 95, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15279918.0, 658.0048, -0.1, 15280602.0, 107.64334)
# ('Total Cost: ', 15280602.0)
# Checking svalue <rvalue:  0.3455
# ================================
# ================================
# Checking svalue <rvalue:  0.3455
# Checking svalue <rvalue:  0.3455
# Epoch = 96, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15245368.0, 657.3263, -0.1, 15246051.0, 107.515045)
# ('Total Cost: ', 15246051.0)
# Checking svalue <rvalue:  0.3455
# ================================
# ================================
# Checking svalue <rvalue:  0.345625
# Checking svalue <rvalue:  0.345625
# Epoch = 97, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15210877.0, 656.64795, -0.1, 15211560.0, 107.38683)
# ('Total Cost: ', 15211560.0)
# Checking svalue <rvalue:  0.345625
# ================================
# ================================
# Checking svalue <rvalue:  0.345625
# Checking svalue <rvalue:  0.345625
# Epoch = 98, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15176446.0, 655.97034, -0.1, 15177128.0, 107.2587)
# ('Total Cost: ', 15177128.0)
# Checking svalue <rvalue:  0.345625
# ================================
# ================================
# Checking svalue <rvalue:  0.345625
# Checking svalue <rvalue:  0.345625
# Epoch = 99, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15142078.0, 655.29297, -0.1, 15142759.0, 107.13063)
# ('Total Cost: ', 15142759.0)
# Checking svalue <rvalue:  0.345625
# ================================
# ================================
# Checking svalue <rvalue:  0.34575
# Checking svalue <rvalue:  0.34575
# Epoch = 100, r = 0.100000
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15107770.0, 654.61584, -0.1, 15108451.0, 107.00264)
# ('Total Cost: ', 15108451.0)
# Checking svalue <rvalue:  0.34575
# ================================
# ================================
# Session Closed!!!
# Writing file to  /Users/raghav/Documents/Uni/NIPS-2018/experiments/scores/Synthetic_OC-NN_Sigmoid.csv

# %%
print rstar_OCNN
# Out:
# 0.1

# %% [markdown]
# Plot the true density, the 10% quantile threshold for the density, and the OC-SVM predictions.

# %%
srn.set(font_scale = 2.5);
plt.figure(figsize = (8,6));

rStar = np.percentile(pStar(XTe), q = 100 * 0.10)

plt.plot(XTe, pStar(XTe),                        '.-', linewidth=8, markersize=24);
plt.plot([0,1], [rStar,rStar],                   '--', linewidth=4, markersize=24);
plt.plot([0,1], [rstar_OCNN,rstar_OCNN],         '-.', linewidth=4, markersize=24); # Optimal r value
plt.plot(XTe, test_decisionScore,      '.-', linewidth=6, markersize=8, alpha=0.125); # decision score
plt.ylim((-500, 500))
plt.xlabel('x'); plt.ylabel('p(x)');
plt.savefig('beta_test.pdf', bbox_inches = 'tight');
