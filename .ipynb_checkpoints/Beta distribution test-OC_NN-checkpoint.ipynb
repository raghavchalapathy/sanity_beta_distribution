# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy   as np
import sklearn as skl

import matplotlib.pyplot as plt
import seaborn           as srn

from sklearn.model_selection       import train_test_split
from sklearn.svm                   import OneClassSVM
from sklearn.kernel_approximation  import Nystroem
from sklearn.neighbors             import KernelDensity
from sklearn.model_selection       import GridSearchCV
from sklearn.metrics               import pairwise_distances
from scipy.stats                   import beta
import random
import numpy as np
import random
import numpy as np
import seaborn as sns, numpy as np
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import sys
from sklearn import svm
import time
import tensorflow as tf
from sklearn.metrics import precision_score,accuracy_score
import csv
from itertools import izip_longest

# %% [markdown]
# Generate samples from a Beta(2, 2) distribution.

# %%
np.random.seed(42)
N = 10**4

X     = beta.rvs(a = 2, b = 2, size = N)[:,np.newaxis]
pStar = lambda x: beta.pdf(x, a = 2, b = 2)

XTr, XTe = train_test_split(X, train_size = 0.80, test_size = 0.20, random_state = 42)
XTe      = XTe[np.argsort(XTe.flatten()),:]

# %%
# results = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/sanity_results/"
# decision_scorePath = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/scores/"
# df_usps_scores  = {}
# activations = ["Linear","Sigmoid"]
# methods = ["Linear","RBF"]
# path = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/scores/"

results = "./sanity_results/"
decision_scorePath = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/scores/"
df_usps_scores  = {}
activations = ["Linear","Sigmoid"]
methods = ["Linear","RBF"]
path = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/scores/"
outfile = "/Users/raghav/Documents/Uni/NIPS-2018/experiments/sanity_beta_distribution/weights/"
nu = 0.1

def write_Scores2Csv(train, trainscore, test, testscore,filename):

    data = np.concatenate((train, test))
    score= np.concatenate((trainscore,testscore))
    data = data.tolist()
    score = score.tolist()
    with open(filename, 'a') as myfile:
        wr = csv.writer(myfile)
        wr.writerow(("x", "score"))
    for row in range(0,len(data)):
        with open(filename,
                  'a') as myfile:
            wr = csv.writer(myfile)

            wr.writerow((" ".join(str(x) for x in data[row]), " ".join(str(x) for x in score[row])))


def write_decisionScores2Csv(path, filename, positiveScores, negativeScores):

    newfilePath = path+filename
    print "Writing file to ", path+filename
    poslist = positiveScores.tolist()
    neglist = negativeScores.tolist()

    # rows = zip(poslist, neglist)
    d = [poslist, neglist]
    export_data = izip_longest(*d, fillvalue='')
    with open(newfilePath, 'w') as myfile:
        wr = csv.writer(myfile)
        wr.writerow(("Normal", "Anomaly"))
        wr.writerows(export_data)
    myfile.close()

    return


def tf_OneClass_NN_sigmoid(data_train,data_test):

    tf.reset_default_graph()

    train_X = data_train

    RANDOM_SEED = 42
    tf.set_random_seed(RANDOM_SEED)

     # Layer's sizes
    x_size = train_X.shape[1]   # Number of input nodes: 4 features and 1 bias
    h_size = 200                # Number of hidden nodes
    y_size = 1   # Number of outcomes (3 iris flowers)
    D = x_size
    K = h_size

    theta = np.random.normal(0, 1, K + K*D + 1)
    rvalue = np.random.normal(0,1,(len(train_X),y_size))
  

    def init_weights(shape):
        """ Weight initialization """
        weights = tf.random_normal(shape,mean=0, stddev=0.5)
        return tf.Variable(weights,trainable=False)

    def forwardprop(X, w_1, w_2):
        """
        Forward-propagation.
        IMPORTANT: yhat is not softmax since TensorFlow's softmax_cross_entropy_with_logits() does that internally.
        """
        X = tf.cast(X, tf.float32)
        w_1 = tf.cast(w_1, tf.float32)
        w_2 = tf.cast(w_2, tf.float32)
        h    = tf.nn.sigmoid(tf.matmul(X, w_1))  # The \sigma function
        yhat = tf.matmul(h, w_2)  # The \varphi function
        return yhat

#     g   = lambda x : 1/(1 + tf.exp(-x))
#     g   = lambda x : tf.nn.sigmoid(x)
    g   = lambda x : (1/np.sqrt(h_size) )*tf.cos(x/0.02)

    def nnScore(X, w, V, g,bias1,bias2):
        X = tf.cast(X, tf.float32)
        w = tf.cast(w, tf.float32)
        V = tf.cast(V, tf.float32)
        y_hat =tf.matmul(g((tf.matmul(X, w)+bias1)), V) +bias2
#         return tf.matmul(g((tf.matmul(X, w))), V)
        return y_hat

    def relu(x):
        y = x
        y[y < 0] = 0
        return y
    
    
       # For testing the algorithm
    def compute_LossValue(X, nu, w1, w2, g, r,bias1,bias2):
        w = w1
        V = w2

        X = tf.cast(X, tf.float32)
        w = tf.cast(w1, tf.float32)
        V = tf.cast(w2, tf.float32)
        term1 = 0.5 * tf.reduce_sum(tf.square(w))
        term2 = 0.5 * tf.reduce_sum(tf.square(V))


#         term3 = 1 / nu * tf.reduce_mean(tf.maximum(0.0, r - nnScore(X, w, V, g,bias1,bias2)))
       
        term3 = 1 / nu * tf.reduce_mean(tf.nn.relu(r - nnScore(X, w, V, g,bias1,bias2)))
        term4 = -r
     
        y_hat = nnScore(X, w, V, g,bias1,bias2)
    
        totalCost = term1 + term2 + term3 + term4
        
        loss=   [term1,term2,term3,term4,totalCost,y_hat]
        return loss
    
    
    def ocnn_obj(theta, X, nu, w1, w2, g,r,bias1,bias2):

        w = w1
        V = w2


        X = tf.cast(X, tf.float32)
        w = tf.cast(w1, tf.float32)
        V = tf.cast(w2, tf.float32)


        term1 = 0.5  * tf.reduce_sum(w**2)
        term2 = 0.5  * tf.reduce_sum(V**2)
        term3 = 1/nu * tf.reduce_mean(tf.nn.relu(r - nnScore(X, w, V, g,bias1,bias2)))
        term4 = -r

        return term1 + term2 + term3 + term4


    # For testing the algorithm
    test_X = data_test


    # Symbols
    X = tf.placeholder("float32", shape=[None, x_size])

    r = tf.get_variable("r", dtype=tf.float32,shape=(),trainable=False)

    # Weight initializations
    w_1 = init_weights((x_size, h_size))
    #     w_2 = init_weights((h_size, y_size))
    weights = tf.random_normal((h_size, y_size),mean=0, stddev=0.1)
    w_2 =  tf.Variable(weights)
    
    bias1 = tf.Variable(initial_value=[[1.0]], dtype=tf.float32,trainable=False)
    bias2 = tf.Variable(initial_value=[[1.0]], dtype=tf.float32,trainable=False)

    # Forward propagation
    yhat    = forwardprop(X, w_1, w_2)
    predict = tf.argmax(yhat, axis=1)


    # Backward propagation
    # cost    = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=yhat))
    cost    = ocnn_obj(theta, X, nu, w_1, w_2, g,r,bias1,bias2)
#     updates = tf.train.GradientDescentOptimizer(0.0001).minimize(cost)
    updates = tf.train.AdamOptimizer(4.7 * 1e-1).minimize(cost)

    # Run SGD
    sess = tf.Session()
    init = tf.global_variables_initializer()
    sess.run(init)
    rvalue = 0.1
    start_time = time.time()
    for epoch in range(100):
            # Train with each example
                sess.run(updates, feed_dict={X: train_X, r:rvalue})
                
               
                with sess.as_default():
                    svalue = nnScore(train_X, w_1, w_2, g,bias1,bias2)  
                    print "Checking svalue <rvalue: ",np.mean(svalue.eval() < rvalue)
                    rval = svalue.eval()
                    rvalue = np.percentile(rval,q=100*nu)
                    
                    print "Checking svalue <rvalue: ",np.mean(svalue.eval() < rvalue)
                    costvalue = compute_LossValue(train_X, nu, w_1, w_2, g, rvalue,bias1,bias2)
                    term1 = costvalue[0].eval()
                    term2 = costvalue[1].eval()
                    term3 = costvalue[2].eval()
                    term4 = costvalue[3]
                    term5 = costvalue[4].eval()
                    yval = costvalue[5].eval()
  
                print("Epoch = %d, r = %f"
                  % (epoch + 1,rvalue))
                print ("Cost:(term1,term2,term3,term4,term5,yhat) ", np.mean(term1),np.mean(term2),(term3),np.mean(term4),np.mean(term5),np.mean(yval))
                print ("Total Cost: ",np.mean(term5))
                
                with sess.as_default():
                    print "Checking svalue <rvalue: ",np.mean(svalue.eval() < rvalue)
                print "================================"
                print "================================"

    trainTime = time.time() - start_time

    start_time = time.time()
    train = nnScore(train_X, w_1, w_2, g,bias1,bias2)
    test = nnScore(test_X, w_1, w_2, g,bias1,bias2)
    testTime = time.time() - start_time
    with sess.as_default():
        np_w_1= w_1.eval()
        np_w_2= w_2.eval()
        np_bias1= bias1.eval()
        arrayTrain = train.eval()
        arrayTest = test.eval()
    #     rstar = r.eval()

    rstar =rvalue
    sess.close()
    print "Session Closed!!!"


#     pos_decisionScore = arrayTrain-rstar
#     neg_decisionScore = arrayTest-rstar
    pos_decisionScore = arrayTrain
    neg_decisionScore = arrayTest
    # save the w_1 and bias1 to numpy array
    np.save(outfile+"w_1", np_w_1)
    np.save(outfile+"w_2", np_w_2)
    np.save(outfile+"bias1",np_bias1)

    write_Scores2Csv(train_X,pos_decisionScore,test_X,neg_decisionScore,path+"OC_NN.csv")

    write_decisionScores2Csv(decision_scorePath,"Synthetic_OC-NN_Sigmoid.csv",pos_decisionScore,neg_decisionScore)


    return [pos_decisionScore, neg_decisionScore,trainTime,testTime,rstar]

# %% [markdown]
# ### Call OC-NN Sigmoid

# %%
[train_decisionScore, test_decisionScore,trainTime,testTime,rstar_OCNN] = tf_OneClass_NN_sigmoid(XTr,XTe)
# Out:
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 1, r = 0.433719
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 15.561533, 0.051185951, -0.4337187469005585, 41.519062, 0.87872624)
# ('Total Cost: ', 41.519062)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 2, r = 0.893224
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 1.5787867, 0.043272633, -0.89322350621223445, 27.068901, 0.99233913)
# ('Total Cost: ', 27.068901)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.073625
# Checking svalue <rvalue:  0.1
# Epoch = 3, r = 0.906637
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 3.2264266, 0.05580293, -0.90663682222366337, 28.715658, 1.1010703)
# ('Total Cost: ', 28.715658)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.094125
# Checking svalue <rvalue:  0.1
# Epoch = 4, r = 0.912760
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 8.6799526, 0.055142488, -0.91275995373725893, 34.162399, 1.1736846)
# ('Total Cost: ', 34.162399)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 5, r = 1.005043
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 6.1820002, 0.025124539, -1.0050433516502382, 31.542145, 1.1857305)
# ('Total Cost: ', 31.542145)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.064625
# Checking svalue <rvalue:  0.1
# Epoch = 6, r = 1.023663
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 1.5295328, 0.023691449, -1.0236625790596008, 26.869627, 1.1560068)
# ('Total Cost: ', 26.869627)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.1405
# Checking svalue <rvalue:  0.1
# Epoch = 7, r = 1.011237
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.53174853, 0.011645216, -1.0112366318702699, 25.872221, 1.1051941)
# ('Total Cost: ', 25.872221)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.316625
# Checking svalue <rvalue:  0.1
# Epoch = 8, r = 0.843316
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 2.8052423, 0.038899306, -0.84331591129302974, 28.340891, 1.0421804)
# ('Total Cost: ', 28.340891)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.211625
# Checking svalue <rvalue:  0.1
# Epoch = 9, r = 0.719945
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 4.192904, 0.036106896, -0.71994459033012392, 29.849131, 0.98568588)
# ('Total Cost: ', 29.849131)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.045625
# Checking svalue <rvalue:  0.1
# Epoch = 10, r = 0.747247
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 3.0075324, 0.031162651, -0.74724664688110354, 28.631514, 0.9572106)
# ('Total Cost: ', 28.631514)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 11, r = 0.883674
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 1.0344225, 0.014192961, -0.88367369174957278, 26.505005, 0.96082729)
# ('Total Cost: ', 26.505005)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.094875
# Checking svalue <rvalue:  0.1
# Epoch = 12, r = 0.885624
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.37890458, 0.012337747, -0.88562439680099492, 25.845684, 0.99071729)
# ('Total Cost: ', 25.845684)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 13, r = 0.926220
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 1.1775138, 0.012501374, -0.92622031569480889, 26.603859, 1.0362445)
# ('Total Cost: ', 26.603859)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 14, r = 0.961554
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 2.0992343, 0.010480476, -0.96155353188514714, 27.488226, 1.0854371)
# ('Total Cost: ', 27.488226)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.001625
# Checking svalue <rvalue:  0.1
# Epoch = 15, r = 0.985639
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 2.0822992, 0.0083343424, -0.98563901185989378, 27.445059, 1.1268139)
# ('Total Cost: ', 27.445059)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.002125
# Checking svalue <rvalue:  0.1
# Epoch = 16, r = 1.057980
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 1.2838626, 0.016971642, -1.0579799652099611, 26.58292, 1.1490663)
# ('Total Cost: ', 26.58292)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.01575
# Checking svalue <rvalue:  0.1
# Epoch = 17, r = 1.111012
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.59894133, 0.026050376, -1.1110121488571167, 25.854046, 1.1459641)
# ('Total Cost: ', 25.854046)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.45325
# Checking svalue <rvalue:  0.1
# Epoch = 18, r = 1.031462
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.55092263, 0.028425341, -1.0314619064331054, 25.887951, 1.1134324)
# ('Total Cost: ', 25.887951)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.32475
# Checking svalue <rvalue:  0.1
# Epoch = 19, r = 0.964956
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.88350618, 0.031072406, -0.9649560213088989, 26.289688, 1.0698398)
# ('Total Cost: ', 26.289688)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.23675
# Checking svalue <rvalue:  0.1
# Epoch = 20, r = 0.938367
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 1.0540097, 0.0092441812, -0.93836672902107243, 26.464954, 1.0271434)
# ('Total Cost: ', 26.464954)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.146625
# Checking svalue <rvalue:  0.1
# Epoch = 21, r = 0.933841
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.85358733, 0.016332258, -0.93384116291999819, 26.276144, 0.99675)
# ('Total Cost: ', 26.276144)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.055875
# Checking svalue <rvalue:  0.1
# Epoch = 22, r = 0.941760
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.49671769, 0.013751511, -0.94175974130630491, 25.908775, 0.98715317)
# ('Total Cost: ', 25.908775)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.1335
# Checking svalue <rvalue:  0.1
# Epoch = 23, r = 0.931111
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.32579646, 0.016673159, -0.93111083507537851, 25.751425, 1.001622)
# ('Total Cost: ', 25.751425)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.04275
# Checking svalue <rvalue:  0.1
# Epoch = 24, r = 0.954078
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.40500933, 0.017840164, -0.9540779232978821, 25.808836, 1.0304384)
# ('Total Cost: ', 25.808836)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 25, r = 0.997883
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.5687747, 0.012854013, -0.99788259863853446, 25.923811, 1.0645272)
# ('Total Cost: ', 25.923811)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 26, r = 1.032827
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.61184514, 0.012924461, -1.0328270316123962, 25.932007, 1.0925235)
# ('Total Cost: ', 25.932007)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0055
# Checking svalue <rvalue:  0.1
# Epoch = 27, r = 1.060014
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.49471644, 0.0068505676, -1.0600141525268554, 25.781618, 1.1044544)
# ('Total Cost: ', 25.781618)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.173125
# Checking svalue <rvalue:  0.1
# Epoch = 28, r = 1.045621
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.35689753, 0.0034717869, -1.0456207156181334, 25.654814, 1.0968679)
# ('Total Cost: ', 25.654814)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.16625
# Checking svalue <rvalue:  0.1
# Epoch = 29, r = 1.025984
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.31808347, 0.026309548, -1.0259836792945862, 25.658474, 1.0831254)
# ('Total Cost: ', 25.658474)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.224
# Checking svalue <rvalue:  0.1
# Epoch = 30, r = 0.999133
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.34272888, 0.020337328, -0.99913275241851807, 25.704, 1.0643874)
# ('Total Cost: ', 25.704)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.174375
# Checking svalue <rvalue:  0.1
# Epoch = 31, r = 0.981442
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.34136087, 0.014627431, -0.98144229650497439, 25.714611, 1.0510575)
# ('Total Cost: ', 25.714611)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.1375
# Checking svalue <rvalue:  0.1
# Epoch = 32, r = 0.977209
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.29801473, 0.014271467, -0.97720862627029426, 25.675142, 1.0441039)
# ('Total Cost: ', 25.675142)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.15175
# Checking svalue <rvalue:  0.1
# Epoch = 33, r = 0.964256
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.24271376, 0.013155997, -0.96425616145133974, 25.63168, 1.0377743)
# ('Total Cost: ', 25.63168)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.1165
# Checking svalue <rvalue:  0.1
# Epoch = 34, r = 0.957086
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.20709994, 0.026866164, -0.95708555579185484, 25.616947, 1.0343782)
# ('Total Cost: ', 25.616947)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.02575
# Checking svalue <rvalue:  0.1
# Epoch = 35, r = 0.977044
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.19814692, 0.013220902, -0.97704398632049561, 25.57439, 1.0408669)
# ('Total Cost: ', 25.57439)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.137125
# Checking svalue <rvalue:  0.1
# Epoch = 36, r = 0.959121
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.21740122, 0.01805371, -0.9591214656829834, 25.616398, 1.0500931)
# ('Total Cost: ', 25.616398)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0685
# Checking svalue <rvalue:  0.1
# Epoch = 37, r = 0.976287
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.22908056, 0.021949457, -0.97628667354583742, 25.614809, 1.0657139)
# ('Total Cost: ', 25.614809)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 38, r = 1.015581
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.2008144, 0.0077554379, -1.0155807852745056, 25.533054, 1.0827317)
# ('Total Cost: ', 25.533054)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.04625
# Checking svalue <rvalue:  0.1
# Epoch = 39, r = 1.033838
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.18315518, 0.015677221, -1.0338375210762025, 25.505058, 1.0912429)
# ('Total Cost: ', 25.505058)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.28725
# Checking svalue <rvalue:  0.1
# Epoch = 40, r = 1.002941
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.19736047, 0.0075399671, -1.0029414534568786, 25.542025, 1.0874982)
# ('Total Cost: ', 25.542025)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.141125
# Checking svalue <rvalue:  0.1
# Epoch = 41, r = 0.969449
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.19133925, 0.02066155, -0.96944898962974546, 25.582619, 1.0738404)
# ('Total Cost: ', 25.582619)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.063125
# Checking svalue <rvalue:  0.1
# Epoch = 42, r = 0.974242
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.15706836, 0.0060238787, -0.97424193620681765, 25.528915, 1.0597684)
# ('Total Cost: ', 25.528915)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.065125
# Checking svalue <rvalue:  0.1
# Epoch = 43, r = 0.979966
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.12883489, 0.0084998906, -0.97996610403060913, 25.497435, 1.0456611)
# ('Total Cost: ', 25.497435)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.232375
# Checking svalue <rvalue:  0.1
# Epoch = 44, r = 0.963462
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.1155491, 0.0053505395, -0.96346169710159302, 25.497503, 1.0353284)
# ('Total Cost: ', 25.497503)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.14975
# Checking svalue <rvalue:  0.1
# Epoch = 45, r = 0.945958
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.11600699, 0.0047974009, -0.94595843553543091, 25.51491, 1.0376357)
# ('Total Cost: ', 25.51491)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.093875
# Checking svalue <rvalue:  0.1
# Epoch = 46, r = 0.951242
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.12526095, 0.032002494, -0.95124232769012451, 25.546087, 1.048013)
# ('Total Cost: ', 25.546087)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.067375
# Checking svalue <rvalue:  0.1
# Epoch = 47, r = 0.964182
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.13994417, 0.018671293, -0.96418223381042489, 25.534498, 1.0604516)
# ('Total Cost: ', 25.534498)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.039375
# Checking svalue <rvalue:  0.1
# Epoch = 48, r = 0.993323
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.14334466, 0.022873472, -0.99332301616668695, 25.51296, 1.0745217)
# ('Total Cost: ', 25.51296)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.06375
# Checking svalue <rvalue:  0.1
# Epoch = 49, r = 0.998317
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.13825129, 0.01939369, -0.99831731319427486, 25.499392, 1.0854506)
# ('Total Cost: ', 25.499392)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.112125
# Checking svalue <rvalue:  0.1
# Epoch = 50, r = 0.991521
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.1297341, 0.024262657, -0.99152060747146609, 25.502542, 1.0796208)
# ('Total Cost: ', 25.502542)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.125625
# Checking svalue <rvalue:  0.1
# Epoch = 51, r = 0.974054
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.12414914, 0.032591227, -0.97405413985252387, 25.522751, 1.0703971)
# ('Total Cost: ', 25.522751)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.08575
# Checking svalue <rvalue:  0.1
# Epoch = 52, r = 0.989888
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10992528, 0.042203724, -0.98988802433013923, 25.502308, 1.0588317)
# ('Total Cost: ', 25.502308)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.195375
# Checking svalue <rvalue:  0.1
# Epoch = 53, r = 0.941023
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.098539874, 0.013180886, -0.94102314710617063, 25.510763, 1.048313)
# ('Total Cost: ', 25.510763)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.064375
# Checking svalue <rvalue:  0.1
# Epoch = 54, r = 0.954587
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.093594, 0.015835991, -0.95458736419677737, 25.494907, 1.0483376)
# ('Total Cost: ', 25.494907)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.040875
# Checking svalue <rvalue:  0.1
# Epoch = 55, r = 0.964816
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10200308, 0.013984825, -0.96481573581695557, 25.491238, 1.0565851)
# ('Total Cost: ', 25.491238)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.059375
# Checking svalue <rvalue:  0.1
# Epoch = 56, r = 0.987905
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10060522, 0.023863297, -0.98790460228919985, 25.476627, 1.0621243)
# ('Total Cost: ', 25.476627)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.15325
# Checking svalue <rvalue:  0.1
# Epoch = 57, r = 0.983673
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10260893, 0.0092790257, -0.9836726605892181, 25.468281, 1.0703313)
# ('Total Cost: ', 25.468281)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.112875
# Checking svalue <rvalue:  0.1
# Epoch = 58, r = 0.969879
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.12501754, 0.042399373, -0.96987866759300234, 25.537601, 1.074249)
# ('Total Cost: ', 25.537601)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.101625
# Checking svalue <rvalue:  0.1
# Epoch = 59, r = 0.969146
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.12183336, 0.020526789, -0.96914644241333014, 25.513279, 1.071071)
# ('Total Cost: ', 25.513279)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.111
# Checking svalue <rvalue:  0.1
# Epoch = 60, r = 0.961763
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10211749, 0.021422997, -0.96176287531852722, 25.501842, 1.0691568)
# ('Total Cost: ', 25.501842)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.07275
# Checking svalue <rvalue:  0.1
# Epoch = 61, r = 0.968774
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.095385358, 0.010297306, -0.96877375841140745, 25.476974, 1.0678411)
# ('Total Cost: ', 25.476974)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.078375
# Checking svalue <rvalue:  0.1
# Epoch = 62, r = 0.982905
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.095668301, 0.024205722, -0.98290512561798093, 25.477036, 1.0625634)
# ('Total Cost: ', 25.477036)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.14575
# Checking svalue <rvalue:  0.1
# Epoch = 63, r = 0.956052
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.098581702, 0.024180867, -0.95605207085609434, 25.506775, 1.0612586)
# ('Total Cost: ', 25.506775)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.09825
# Checking svalue <rvalue:  0.1
# Epoch = 64, r = 0.957933
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.11318428, 0.040278625, -0.95793256163597107, 25.535595, 1.0612772)
# ('Total Cost: ', 25.535595)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.123125
# Checking svalue <rvalue:  0.1
# Epoch = 65, r = 0.946038
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.11512992, 0.017052589, -0.94603826999664298, 25.526207, 1.0591041)
# ('Total Cost: ', 25.526207)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.099375
# Checking svalue <rvalue:  0.1
# Epoch = 66, r = 0.946616
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.1049099, 0.02829618, -0.94661645293235774, 25.526653, 1.0630274)
# ('Total Cost: ', 25.526653)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 67, r = 0.967777
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.098345548, 0.0089178719, -0.96777657866477973, 25.479551, 1.0692781)
# ('Total Cost: ', 25.479551)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.062375
# Checking svalue <rvalue:  0.1
# Epoch = 68, r = 0.992276
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.095623486, 0.026654854, -0.99227609634399416, 25.470068, 1.0711404)
# ('Total Cost: ', 25.470068)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.125
# Checking svalue <rvalue:  0.1
# Epoch = 69, r = 0.974306
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10367183, 0.025584273, -0.97430557012557983, 25.495016, 1.0723289)
# ('Total Cost: ', 25.495016)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.108875
# Checking svalue <rvalue:  0.1
# Epoch = 70, r = 0.963654
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.12514895, 0.038929626, -0.9636538028717041, 25.540489, 1.0700959)
# ('Total Cost: ', 25.540489)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.138375
# Checking svalue <rvalue:  0.1
# Epoch = 71, r = 0.941791
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.11690686, 0.022280641, -0.94179098010063178, 25.53746, 1.0617664)
# ('Total Cost: ', 25.53746)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.080625
# Checking svalue <rvalue:  0.1
# Epoch = 72, r = 0.955990
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.090831965, 0.03111981, -0.95598972439765928, 25.506027, 1.0597061)
# ('Total Cost: ', 25.506027)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.09225
# Checking svalue <rvalue:  0.1
# Epoch = 73, r = 0.959023
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.090233088, 0.012756529, -0.95902271866798405, 25.484032, 1.0625422)
# ('Total Cost: ', 25.484032)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.052875
# Checking svalue <rvalue:  0.1
# Epoch = 74, r = 0.986714
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.090475395, 0.025492102, -0.98671361207962038, 25.469318, 1.0649028)
# ('Total Cost: ', 25.469318)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.12925
# Checking svalue <rvalue:  0.1
# Epoch = 75, r = 0.971320
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10125931, 0.021663234, -0.97132024765014646, 25.491667, 1.0690792)
# ('Total Cost: ', 25.491667)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.10825
# Checking svalue <rvalue:  0.1
# Epoch = 76, r = 0.962347
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.13709985, 0.038853317, -0.96234657168388371, 25.553671, 1.0707629)
# ('Total Cost: ', 25.553671)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.161375
# Checking svalue <rvalue:  0.1
# Epoch = 77, r = 0.932502
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.13445897, 0.019726086, -0.93250229954719543, 25.561747, 1.064782)
# ('Total Cost: ', 25.561747)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.07475
# Checking svalue <rvalue:  0.1
# Epoch = 78, r = 0.957095
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.098366827, 0.038806271, -0.95709526538848877, 25.520144, 1.06343)
# ('Total Cost: ', 25.520144)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.097125
# Checking svalue <rvalue:  0.1
# Epoch = 79, r = 0.958106
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.097037815, 0.015469285, -0.95810599923133855, 25.494467, 1.0654584)
# ('Total Cost: ', 25.494467)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.056625
# Checking svalue <rvalue:  0.1
# Epoch = 80, r = 0.983421
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10009959, 0.024892205, -0.98342128992080691, 25.481636, 1.06671)
# ('Total Cost: ', 25.481636)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.143375
# Checking svalue <rvalue:  0.1
# Epoch = 81, r = 0.957156
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.11078589, 0.024394728, -0.95715627670288084, 25.518089, 1.0693667)
# ('Total Cost: ', 25.518089)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.090875
# Checking svalue <rvalue:  0.1
# Epoch = 82, r = 0.969046
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.14404309, 0.044577476, -0.96904585361480711, 25.559639, 1.0701289)
# ('Total Cost: ', 25.559639)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.18225
# Checking svalue <rvalue:  0.1
# Epoch = 83, r = 0.916850
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.14512807, 0.023665704, -0.91685017347335818, 25.592009, 1.0631257)
# ('Total Cost: ', 25.592009)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.06325
# Checking svalue <rvalue:  0.1
# Epoch = 84, r = 0.951066
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10243598, 0.03948817, -0.95106648802757265, 25.530922, 1.0614656)
# ('Total Cost: ', 25.530922)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.077625
# Checking svalue <rvalue:  0.1
# Epoch = 85, r = 0.957993
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.098757744, 0.01993211, -0.95799348950386054, 25.500763, 1.064033)
# ('Total Cost: ', 25.500763)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.04925
# Checking svalue <rvalue:  0.1
# Epoch = 86, r = 0.989305
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10397643, 0.027936148, -0.98930467963218682, 25.482674, 1.0673029)
# ('Total Cost: ', 25.482674)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.1475
# Checking svalue <rvalue:  0.1
# Epoch = 87, r = 0.951507
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.12121966, 0.025545802, -0.95150692462921149, 25.535322, 1.0714023)
# ('Total Cost: ', 25.535322)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.081625
# Checking svalue <rvalue:  0.1
# Epoch = 88, r = 0.971644
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.1549523, 0.04663498, -0.9716438353061676, 25.570009, 1.0731784)
# ('Total Cost: ', 25.570009)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.17925
# Checking svalue <rvalue:  0.1
# Epoch = 89, r = 0.913862
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.15361091, 0.024098054, -0.91386157870292661, 25.60391, 1.0651597)
# ('Total Cost: ', 25.60391)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0605
# Checking svalue <rvalue:  0.1
# Epoch = 90, r = 0.952317
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10367127, 0.040232524, -0.95231689214706428, 25.531652, 1.0616997)
# ('Total Cost: ', 25.531652)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.089375
# Checking svalue <rvalue:  0.1
# Epoch = 91, r = 0.959970
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.098030299, 0.03059753, -0.95997013449668889, 25.508722, 1.0627025)
# ('Total Cost: ', 25.508722)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.03325
# Checking svalue <rvalue:  0.1
# Epoch = 92, r = 0.988181
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10494566, 0.019343611, -0.98818103075027464, 25.476175, 1.0675056)
# ('Total Cost: ', 25.476175)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.148625
# Checking svalue <rvalue:  0.1
# Epoch = 93, r = 0.950165
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.12553555, 0.029039264, -0.95016545057296753, 25.544476, 1.0711825)
# ('Total Cost: ', 25.544476)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.079875
# Checking svalue <rvalue:  0.1
# Epoch = 94, r = 0.972128
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.15341005, 0.046372324, -0.97212808132171635, 25.567719, 1.0730938)
# ('Total Cost: ', 25.567719)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.175625
# Checking svalue <rvalue:  0.1
# Epoch = 95, r = 0.911915
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.15283605, 0.025635723, -0.91191478967666628, 25.606623, 1.0647217)
# ('Total Cost: ', 25.606623)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.06575
# Checking svalue <rvalue:  0.1
# Epoch = 96, r = 0.947747
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10703099, 0.040715598, -0.94774715304374701, 25.540066, 1.0612435)
# ('Total Cost: ', 25.540066)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.092875
# Checking svalue <rvalue:  0.1
# Epoch = 97, r = 0.953787
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.099893957, 0.031852949, -0.95378729701042175, 25.518024, 1.0627006)
# ('Total Cost: ', 25.518024)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0
# Checking svalue <rvalue:  0.1
# Epoch = 98, r = 0.986866
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.10515546, 0.015528723, -0.98686568140983588, 25.473885, 1.06794)
# ('Total Cost: ', 25.473885)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.132125
# Checking svalue <rvalue:  0.1
# Epoch = 99, r = 0.964163
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.12256972, 0.024020266, -0.96416324973106382, 25.522493, 1.073149)
# ('Total Cost: ', 25.522493)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Checking svalue <rvalue:  0.0925
# Checking svalue <rvalue:  0.1
# Epoch = 100, r = 0.971897
# ('Cost:(term1,term2,term3,term4,term5,yhat) ', 26.340065, 0.15601459, 0.046289206, -0.97189694046974184, 25.570473, 1.0755836)
# ('Total Cost: ', 25.570473)
# Checking svalue <rvalue:  0.1
# ================================
# ================================
# Session Closed!!!
# Writing file to  /Users/raghav/Documents/Uni/NIPS-2018/experiments/scores/Synthetic_OC-NN_Sigmoid.csv

# %%
print rstar_OCNN
# Out:
# 1.05307840109

# %% [markdown]
# Plot the true density, the 10% quantile threshold for the density, and the OC-SVM predictions.

# %%
srn.set(font_scale = 2.5);
plt.figure(figsize = (8,6));

rStar = np.percentile(pStar(XTe), q = 100 * 0.10)

plt.plot(XTe, pStar(XTe),                        '.-', linewidth=8, markersize=24);
plt.plot([0,1], [rStar,rStar],                   '--', linewidth=4, markersize=24);
plt.plot([0,1], [rstar_OCNN,rstar_OCNN],         '-.', linewidth=4, markersize=24); # Optimal r value
plt.plot(XTe, test_decisionScore,      '.-', linewidth=6, markersize=8, alpha=0.125); # decision score
plt.ylim((-1, 2))
plt.xlabel('x'); plt.ylabel('p(x)');
plt.savefig('beta_test.pdf', bbox_inches = 'tight');
